# %% [markdown]
# # Example of Deduplication

# %%
import pandas as pd
from duplicatesuricate import deduplication as dep
from duplicatesuricate.preprocessing import clean_db

# %% [markdown]
# ## 1. Loading Data

# %% [markdown]
# ### Loading sample data

# %%
df_input_records = pd.read_csv('df_impairs.csv',index_col=0,dtype={'duns':str,'postalcode':str},sep='|')
df_target_records = pd.read_csv('df_pairs.csv',index_col=0,dtype={'duns':str,'postalcode':str},sep='|')
df_input_records.sample(3)
# Out:
#                                                                  name  \
# gid
# 76e834db-6e0c-400a-8f51-98b2652fd479                          datalis
# 5b73dbc1-e030-4d16-a8ce-3935c6094aa7  goodrich sensorsintegrated syst
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18        horizon platforms limited
#
#                                            duns                city  \
# gid
# 76e834db-6e0c-400a-8f51-98b2652fd479  260332779  portet-sur-garonne
# 5b73dbc1-e030-4d16-a8ce-3935c6094aa7  804817070          burnsville
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18  210161671           normanton
#
#                                       postalcode              street  \
# gid
# 76e834db-6e0c-400a-8f51-98b2652fd479       31125  8 avenue gutenberg
# 5b73dbc1-e030-4d16-a8ce-3935c6094aa7  55306-4890   14300 judicial rd
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18     wf6 1zb          rosie road
#
#                                      country_code
# gid
# 76e834db-6e0c-400a-8f51-98b2652fd479           FR
# 5b73dbc1-e030-4d16-a8ce-3935c6094aa7           US
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18           GB

# %% [markdown]
# ### Cleaning that data

# %%
for x in [df_input_records,df_target_records]:
    x = clean_db(x)
df_target_records.sample(3)
# Out:
#                                                     name       duns  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166  goetz service gmbh       None
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6        licatec gmbh  330944281
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc          me systeme       None
#
#                                                  city postalcode  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166        goppingen      73037
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6  brand erbisdorf       9618
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc          kolleda      99625
#
#                                                   street country_code  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166  2 2 zillenhardtstr           DE
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6            7 erzstr           DE
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc  2 august bebel str           DE
#
#                                      name_wostopwords street_wostopwords  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166            goetz      2 zillenhardt
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6          licatec              7 erz
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc       me systeme     bebel 2 august
#
#                                      name_acronym postalcode_1stdigit  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166          gsg                   7
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6           lg                   9
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc           ms                   9
#
#                                      postalcode_2digits  name_len  \
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166                 73        18
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6                 96        12
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc                 99        10
#
#                                       hasairbusname  isbigcity
# gid
# efd9b1bc-6310-4eb9-8d6f-42c4d8375166              0          0
# 546c2c52-71cd-4880-ad20-e0e9a0ff2cc6              0          0
# 875615ec-9b8a-4a46-a4b9-a7b1d0bc08bc              0          0

# %% [markdown]
# # Machine Learning - based deduplication

# %% [markdown]
# ## 1. Training set

# %% [markdown]
# ### Option 1: Creating a training table for the decision model
# #### Step 1 Loading a supervised learning table

# %%
km=pd.read_csv('known_matches3.csv')
rowmax=None
print('nrows: {}'.format(km.shape[0]))
km = km.loc[km['ix_source'].isin(df_input_records.index)]
km = km.loc[km['ix_target'].isin(df_target_records.index)]
print('nrows: {}'.format(km.shape[0]))
y=km['y_true'].value_counts()
print('Positive labels:{0:.0%}'.format(y[1]/y.sum()))
del y
km.sample(3)
# Out:
# nrows: 3770
# nrows: 43
# Positive labels:100%
#                                  ix_source  \
# 1034  ea502496-0ffc-4d51-8ea1-8e4789ac3a1e
# 1118  dcecaed1-df61-4e48-84e3-f990e5b78974
# 986   b37479a6-1be0-435f-8d93-08e98199e844
#
#                                  ix_target  y_proba  y_true
# 1034  0bcf1f54-8923-4e65-9012-3de0592a4509   1.0000     1.0
# 1118  5579240e-0518-4b54-9f1a-d04a89569355   0.9995     1.0
# 986   9d90ddbc-534f-4edd-91b9-a4acd9f6d751   1.0000     1.0

# %% [markdown]
# #### Step 2 Creating the training table

# %%
dummymodel=dep.DummyClassifier(scoredict={'fuzzy':['name','name_wostopwords',
                                               'street','street_wostopwords',
                                               'city'],
                                      'exact':['duns','country_code'],
                                      'token':['name','name_wostopwords',
                                               'street','street_wostopwords'],
                                      'acronym':['name','name_wostopwords']})
sur=dep.Suricate(input_records=df_input_records,
                target_records=df_target_records,
                classifier=dummymodel)
training_table=sur.build_training_table(inputs=km['ix_source'].values,
                                        targets=km['ix_target'].values,
                                        y_true=km['y_true'].values,
                                       with_proba=False).fillna(0)
#x2=sur.chain_build_labelled_table(inputs=s_inputs,targets=s_targets)
print(training_table['y_true'].value_counts())
training_table.sample(3)
# Out:
# 1.0    43
# Name: y_true, dtype: int64
#                                                                            city_fuzzyscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd              1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344              1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d              1.0
#
#                                                                            country_code_exactscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                      1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                      1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                      1.0
#
#                                                                            duns_exactscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd              0.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344              0.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d              0.0
#
#                                                                            name_acronymscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd              -0.52
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344              -0.64
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d              -0.64
#
#                                                                            name_fuzzyscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd            -0.02
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344             1.00
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d             1.00
#
#                                                                            name_tokenscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd              1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344              1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d              1.0
#
#                                                                            name_wostopwords_acronymscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                           0.00
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                           0.00
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                          -0.64
#
#                                                                            name_wostopwords_fuzzyscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                        -0.02
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                         1.00
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                         1.00
#
#                                                                            name_wostopwords_tokenscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                          1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                          1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                          1.0
#
#                                                                            street_fuzzyscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                1.0
#
#                                                                            street_tokenscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                1.0
#
#                                                                            street_wostopwords_fuzzyscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                            1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                            1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                            1.0
#
#                                                                            street_wostopwords_tokenscore  \
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd                            1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344                            1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d                            1.0
#
#                                                                            y_true
# ix_source                            ix_target
# e442ea3c-895b-44b2-bdf2-bda0aa36bf18 716a90f4-0066-4e26-a727-9575802f9ffd     1.0
# 21c09dde-cff3-4c45-a2f1-46a99e6e1587 1b932c6a-3719-4f78-ba6e-c4ffdf0cc344     1.0
# 424803ef-a428-46eb-999b-d68429aedf5d e974ef74-3bf5-45c2-9273-c44f73945a4d     1.0

# %% [markdown]
# ### Or Option 2: Loading an existing table

# %%
training_table=pd.read_csv('trainining_table3.csv',sep=',',index_col=[0,1])
training_table.sample(3)
# Out:
#                                                                            city_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981              1.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c              1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc             -1.0
#
#                                                                            country_code_exactscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                      1.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                      1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                      1.0
#
#                                                                            duns_exactscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981              0.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c              0.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc              0.0
#
#                                                                            hasairbusname_source  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                     0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                     0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                     0
#
#                                                                            hasairbusname_target  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                     0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                     0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                     0
#
#                                                                            isbigcity_source  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                 1
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                 0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                 0
#
#                                                                            isbigcity_target  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                 1
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                 0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                 0
#
#                                                                            name_acronym_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                     0.72
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                     1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                     0.34
#
#                                                                            name_acronymscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981               1.00
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c              -0.52
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc               0.00
#
#                                                                            name_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981             0.86
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c             1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc            -0.46
#
#                                                                            name_tokenscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981             1.00
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c             1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc            -0.46
#
#                                                                            name_wostopwords_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                         0.86
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                         1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                        -0.46
#
#                                                                            name_wostopwords_tokenscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                         1.00
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                         1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                        -0.46
#
#                                                                            postalcode_1stdigit_exactscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                             0.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                             1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                             1.0
#
#                                                                            postalcode_2digits_exactscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                            0.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                            1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                            1.0
#
#                                                                            postalcode_exactscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                    0.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                    1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                    0.0
#
#                                                                            postalcode_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                  -0.14
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                   1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                   0.20
#
#                                                                            street_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981              -0.52
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c               1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc              -0.70
#
#                                                                            street_tokenscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981              -0.42
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c               1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc               1.00
#
#                                                                            street_wostopwords_fuzzyscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                          -0.58
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                           1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                          -0.62
#
#                                                                            street_wostopwords_tokenscore  \
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981                          -0.44
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c                           1.00
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc                           1.00
#
#                                                                            y_true
# ix_source                            ix_target
# 3b79b4b8-04f1-4198-8dab-9abd5c3b1e2b aed69ed2-8438-41b5-a7f1-47046dae5981     1.0
# dcc308de-62f6-4c91-bd0e-b7ad77424c9c c14c6e12-efc9-486d-9b89-d8b50be8e36c     1.0
# 0472d735-b408-4d20-9209-858c5ac35232 b79a078a-156f-421b-934f-25da716214cc     0.0

# %% [markdown]
# ## Use a Scikit-Learn Classifier
# Go to the end of the notebook to see how you can use a SparkML classifier or a Rule-based classifier

# %% [markdown]
# optional : select yourself the evaluator you need

# %%
from sklearn.ensemble import RandomForestClassifier
mymodel = RandomForestClassifier(n_estimators=1000,max_depth=30,min_samples_split=3)
classifier=dep.ScikitLearnClassifier(model=mymodel)

# %% [markdown]
# or use the default one (RandomForest)

# %%
classifier=dep.ScikitLearnClassifier()

# %% [markdown]
# fit

# %%
X_train = training_table.iloc[:,:-1].astype(float)
y_train= training_table.iloc[:,-1].astype(int)
classifier.fit(X=X_train,y=y_train)
# Out:
# shape of training table  (3770, 21)
# number of positives in table 1389
# precision score on training data: 0.987883107627
# recall score on training data: 0.997840172786
# time elapsed 7.686195 seconds

# %% [markdown]
# ### Optional: add filtering rules to speed up the scoring process

# %% [markdown]
# filter the target records on records that match exactly the country code, or that match the duns number of the query

# %%
filterdict={'all':['country_code'],
           'any':['duns']}

# %% [markdown]
# from those filtered records, filter on records who have a roughly similar name or address, or share the same duns

# %%
intermediate_thresholds={'name_wostopwords_fuzzyscore':0.5,'street_wostopwords_fuzzyscore':0.5, 'duns_exactscore':1.0,'aggfunc':'any'}

# %% [markdown]
# putting all together

# %%
sur=dep.Suricate(input_records=df_input_records,target_records=df_target_records,
                 filterdict=filterdict,
                 intermediate_thresholds=intermediate_thresholds,
                 classifier=classifier)

# %% [markdown]
# # Launching the deduplication

# %% [markdown]
# ### Possibility 1: return only good matches (for run mode)

# %%
res=sur.start_linkage(n_matches_max=None,with_proba=False)
x=sur.build_visualcomparison_table(inputs=res['ix_source'].values,targets=res['ix_target'].values,display=['name',],fuzzy=['street'],exact=['duns'])
x.sample(3)
# Out:
# starting deduplication at 2018-02-13 16:28:17.845890
# 1 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.293408 s
# 2 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.33683 s
# 3 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.248936 s
# 4 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.251387 s
# 5 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.284098 s
# 6 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.299354 s
# 7 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.26093 s
# 8 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.317409 s
# 9 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.308501 s
# 10 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.281727 s
# finished work at 2018-02-13 16:28:20.731822
#                                                                                      name_source  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66                h media
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c  botschaft afghanistan
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56         berlinzeppelin
#
#                                                                                      name_target  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66                h media
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c  botschaft afghanistan
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56         berlinzeppelin
#
#                                                                           duns_source  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66   372377817
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c        None
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56        None
#
#                                                                           duns_target  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66        None
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c        None
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56        None
#
#                                                                            duns_exactscore  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66              0.0
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c              0.0
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56              0.0
#
#                                                                               street_source  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66     329 heistraat
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c   3 taunusstraaye
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56  4 rottweiler str
#
#                                                                               street_target  \
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66     329 heistraat
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c       3 taunusstr
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56  4 rottweiler str
#
#                                                                            street_fuzzyscore
# ix_source                            ix_target
# 31ea5edd-2c80-40ca-85ca-b6768a941d1e 7ff2b1d2-bf47-4b26-849a-0d150fca7b66                1.0
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c                0.7
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56                1.0

# %% [markdown]
# ### Possibility 2: return a probability vector to build a supervised learning table
# this will give you the  {n_matches_max} most probable records, and thus help to train the tool with records on the decision frontier

# %%
# return the 5 most probable matches of the query and the associated probabilities
res=sur.start_linkage(n_matches_max=5,with_proba=True)
# Out:
# starting deduplication at 2018-02-13 16:28:20.843730
# 1 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.314011 s
# 2 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.196651 s
# 3 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.340603 s
# 4 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.349558 s
# 5 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.374056 s
# 6 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.416584 s
# 7 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.329333 s
# 8 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.229988 s
# 9 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.238179 s
# 10 of 10 inputs records deduplicated | found 1 of 5 max possible matches | time elapsed 0.324664 s
# finished work at 2018-02-13 16:28:23.962351

# %%
x=sur.build_visualcomparison_table(inputs=res['ix_source'].values,targets=res['ix_target'].values,display=['name',],fuzzy=['street'],exact=['duns'],
                                   y_proba=res['y_proba'])
x.sort_values(by='y_proba',ascending=True).head(3)
# Out:
#                                                                                        name_source  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc  l amphitryon restaurant
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e                      vds
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c                  ucon ag
#
#                                                                                            name_target  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc                 alter ego 31
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e     vds schadenverhtung gmbh
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c  ucon ag containersysteme kg
#
#                                                                           duns_source  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc   779097252
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e        None
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c   341829459
#
#                                                                           duns_target  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc   779097252
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e   332836506
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c   341057797
#
#                                                                            duns_exactscore  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc              1.0
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e              0.0
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c             -1.0
#
#                                                                                    street_source  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc      chemin de gramont
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e            29 rheinstr
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c  122 sechsheldener str
#
#                                                                                street_target  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc  chemin de gramont
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e           rheinstr
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c  sechsheldener str
#
#                                                                            street_fuzzyscore  \
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc               1.00
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e               0.68
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c               0.78
#
#                                                                            y_proba
# ix_source                            ix_target
# c204c7b7-66fd-4e55-99a4-abf647dd6b3c 7a17d0c9-5992-43db-9580-c1c6cf16cdbc   0.9540
# f3bfed60-958f-454d-8aeb-8674989f7b35 fa96a218-64c7-48b5-8156-2023308ba14e   0.9800
# 4de8d106-40f7-45cc-a0ac-27fbfe94d7fb 0f8eb8df-0881-4d88-af56-b1b75421cd4c   0.9825

# %% [markdown]
# # More possibilites: other kind of classifiers
# ----

# %% [markdown]
# ## Rule-based classifier
# In place of the model learning from training data, you hard-code some rules.
# It is useful if you want to have a predictable and explainable model.

# %%
# example:
hard_threshold = {'name_tokenscore': 0.7,
                  'street_tokenscore': 0.7}
# this hard coded function will take as input r : the row of the scoring
# if one one the score for the row is below the threshold, it will return 0
# you can
def hardcodedfunc(r):
    r = r.fillna(0)
    for k in hard_threshold.keys():
        if r[k] < hard_threshold[k]:
            return 0
    else:
        return 1
# What is important is to note all the columns needed for scoring so the tool knows which score to calculate
score_cols = list(hard_threshold.keys())

# %%
classifier = dep.RuleBasedClassifier(used_cols=score_cols,
                        eval_func=hardcodedfunc)

# %% [markdown]
# ## Spark it! Using a SparkML Model
# The bigger the target records dataset is, the more calculations there are to perform, the slower this algorithm goes.
# One crude solution is to throw more computers at the problem: using Spark for parallel computing.

# %% [markdown]
# #### With an sqlContext
# do not forget to update the spark context if the name of the module if necessary

# %%
import findspark,pyspark
from pyspark.sql import SQLContext
#mypath='/Users/paulogier/Documents/8-PythonProjects/duplicatesuricate/duplicatesuricate/'
sc = pyspark.SparkContext(appName="DuplicateSuricate")
sqlCtx = SQLContext(sc)

# %% [markdown]
# #### Init and fit classifier.
# Fit is done sklearn-style with model.fit(X,y) (and accepts dataframe as inputs) for consistency with the other classifiers

# %%
classifier = dep.SparkClassifier(sqlContext=sqlCtx)
classifier.fit(X_train,y_train)
# Out:
# shape of training table  (3770, 21)
# number of positives in table 1389
# precision score on training data: 0.947513812155
# recall score on training data: 0.987760979122
# time elapsed 14.149353 seconds

# %% [markdown]
# #### Init the Suricate interface with the sparkML
# there is an additional argument spark = True to let the classifier know that you have initialized an sqlContext in the evaluator

# %%
sur = dep.Suricate(input_records=df_input_records,target_records=df_target_records,
                 filterdict=filterdict,
                 intermediate_thresholds=intermediate_thresholds,
                 classifier=classifier,spark = True)

# %%
res=sur.start_linkage(n_matches_max=None,with_proba=False)
x=sur.build_visualcomparison_table(inputs=res['ix_source'].values,
                                   targets=res['ix_target'].values,
                                   display=['name',],fuzzy=['street'],
                                   exact=['duns'])
x.sample(3)
# Out:
# starting deduplication at 2018-02-13 16:28:44.553932
# 1 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.584294 s
# 2 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.354111 s
# 3 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.369066 s
# 4 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.62118 s
# 5 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.365401 s
# 6 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.367494 s
# 7 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.411254 s
# 8 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.418704 s
# 9 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.435261 s
# 10 of 10 inputs records deduplicated | found 1 of None max possible matches | time elapsed 0.290295 s
# finished work at 2018-02-13 16:28:48.775469
#                                                                                                    name_source  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476  bildungswerk der wirtschaft hamburg
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56                       berlinzeppelin
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c                botschaft afghanistan
#
#                                                                                                    name_target  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476  bildungswerk der wirtschaft hamburg
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56                       berlinzeppelin
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c                botschaft afghanistan
#
#                                                                           duns_source  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476        None
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56        None
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c        None
#
#                                                                           duns_target  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476        None
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56        None
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c        None
#
#                                                                            duns_exactscore  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476              0.0
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56              0.0
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c              0.0
#
#                                                                               street_source  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476   10 kapstadtring
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56  4 rottweiler str
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c   3 taunusstraaye
#
#                                                                               street_target  \
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476   10 kapstadtring
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56  4 rottweiler str
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c       3 taunusstr
#
#                                                                            street_fuzzyscore
# ix_source                            ix_target
# 6097f4c6-8515-41fb-b5e5-549c81140848 f704e1f0-b240-4461-a741-b41b5c30b476                1.0
# 5ff704ee-399e-4fbd-b604-51b6ced944dd af8133f8-361f-494e-92dc-ab3c72637d56                1.0
# e2a2da69-3aa4-44e2-ae5b-4bbd2cbdc238 c906f2e3-bd4c-4785-9d60-95f19579a04c                0.7
